# %% [markdown]
# # Getting Started with the Air Force Arcade
#
# ---
#
# In this notebook, we will introduce you to the Air Force Arcade and reinforcement learning by demonstrating some basic functionality of the environments, the basics of gym environments, and finally will train a small [Deep Q Network (DQN)](https://arxiv.org/pdf/1312.5602.pdf) to get you started.

# %% [markdown]
# ## Step 0: About the Environment
#
# The `Aerial Refuelling` environment places a quadcopter (the drone) in an arena with a ball launcher.
# The drone must avoid the launched balls while moving towards and staying hovering on a fixed waypoint in the environment.

# %% [markdown]
# __Rewards__

# %% [markdown]
# ## Step 1: Start the Environment
#
# First, we will import the necessary packages.

# %%
import gym
import airforce_arcade
import numpy as np
from collections import deque
import torch
import matplotlib.pyplot as plt
import datetime
import copy
from torch.autograd import Variable
import random
from PIL import Image
from IPython.display import clear_output
import math
import time
from gym.spaces import Dict, Discrete, Box, Tuple
# %matplotlib inline

# %% [markdown]
# Now we will create gym environment. In this step, we use OpenAI's [Gym](https://gym.openai.com/) API to relay the information from our game to Python so we can capture the relevant information.

# %%
# create and launch the environment
env  =  gym.make('CartPole-v1')

# %%
# Demonstration
env = gym.envs.make("CartPole-v1")


def get_screen():
    ''' Extract one step of the simulation.'''
    screen = env.render(mode='rgb_array').transpose((2, 0, 1))
    screen = np.ascontiguousarray(screen, dtype=np.float32) / 255.
    return torch.from_numpy(screen)

# Speify the number of simulation steps
num_steps = 2

# Show several steps
for i in range(num_steps):
    clear_output(wait=True)
    env.reset()
    plt.figure()
    plt.imshow(get_screen().cpu().permute(1, 2, 0).numpy(),
               interpolation='none')
    plt.title('CartPole-v0 Environment')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %% [markdown]
# ## Step 2: Examine the State and Action Spaces of the Environment

# %%
# number of actions
action_size = env.action_space
print('Action Space:', action_size)

# examine the state space 
state = env.observation_space
print('Observations look like:', state)
# Out:
# Action Space: Discrete(2)
# Observations look like: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
state = env.reset()
state

# %%
def plot_res(values, title=''):   
    ''' Plot the reward curve and histogram of results over time.'''
    # Update the window after each episode
    clear_output(wait=True)
    
    # Define the figure
    f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
    f.suptitle(title)
    ax[0].plot(values, label='score per run')
    ax[0].axhline(195, c='red',ls='--', label='goal')
    ax[0].set_xlabel('Episodes')
    ax[0].set_ylabel('Reward')
    x = range(len(values))
    ax[0].legend()
    # Calculate the trend
    try:
        z = np.polyfit(x, values, 1)
        p = np.poly1d(z)
        ax[0].plot(x,p(x),"--", label='trend')
    except:
        print('')
    
    # Plot the histogram of results
    ax[1].hist(values[-50:])
    ax[1].axvline(195, c='red', label='goal')
    ax[1].set_xlabel('Scores per Last 50 Episodes')
    ax[1].set_ylabel('Frequency')
    ax[1].legend()
    plt.show()

# %%
def random_search(env, episodes, 
                  title='Random Strategy'):
    """ Random search strategy implementation."""
    final = []
    for episode in range(episodes):
        state = env.reset()
        done = False
        total = 0
        while not done:
            # Sample random actions
            action = env.action_space.sample()
            # Take action and extract results
            next_state, reward, done, _ = env.step(action)
            # Update reward
            total += reward
            if done:
                break
        # Add to the final reward
        final.append(total)
        plot_res(final,title)
    return final

# %% [markdown]
# You should see a result that looks like:
# ```
# Action Space: MultiDiscrete([3 3 3 3])
# States look like: Box(-inf, inf, (1254,), float32)
# ```
#
# So what does this mean?
#
# For our `DroneDodgeBall` environment, the drone has `4` different discrete actions it can take, with a zero, low, or high action for each.
# These correspond to roll, pitch, thrust, and yaw.
#
# For the state space, these are the observations that the drone receives.
# These are the inputs to your model and what your RL agent learns to recognize and take actions off of.
# In `DroneDodgeBall`, there are `1254` observations representing the drone's ray-based perception of its environment and a 6-vector of nomalized drone position and relative waypoint position.

# %% [markdown]
# ## Step 3: Take Random Actions
#
# In this next cell, we will see how the Gym API interacts with the environment by taking random actions.
# We will also explore how to receive information from the environment that will allow us to train our agents.
#
# You should be able to view the drone's behaviors in the `DroneDodgeBall` game window.
# Since the agent will be making random movements, it will look a bit erratic.

# %%
random_s = random_search(env, 10000)

# %% [markdown]
# ## Step 4: Train your First Model
#
# Unity can sometimes be finicky.
# If you can't get training to start, or it seems that the notebook is lagging, restart your kernel and run steps 0-2.
#
# ![Kernel Restart](images/kernel_restart.png)
#
# __Note:__ These environments are advanced and will require significant training.
# The code provided demonstrates the basics of training a model but will most likely not train a highly sophisticated autonomous agent.

# %% [markdown]
# __Training a Deep Q-Network__
#
# This starter code runs for only 50 episodes.
# On a local computer, this can take between 5-10 minutes.
# You may notice that the agent doesn't really learn much.
# In fact, our training required several thousand training episodes to begin to learn appropriate behaviors.
#
# There are two supporting files required to run this code:
# - `dqn_agent.py` defines the functions of the agent, including how to select actions, take steps, and save experiences for your networks to train on
# - `model.py` is the defined architecture of the neural network. In this example, it's a small 3 layer network with 64 hidden nodes per layer.

# %%
from dqn_agent import Agent
agent = Agent(state_size=4, action_size=2, seed=42)

def dqn(n_episodes=10000, max_t=10000, eps_start=1.0, eps_end=0.01, eps_decay=0.999):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps)
            next_state, reward, done, info = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
#         print('\rEpisode {}\tAverage Score: {:.2f}\n'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 10 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
    return scores

scores = dqn()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# State Size: 4
# Action_size: 2
# Episode 10	Average Score: 23.40
# Episode 20	Average Score: 25.10
# Episode 30	Average Score: 25.07
# Episode 40	Average Score: 22.73
# Episode 50	Average Score: 24.70
# Episode 60	Average Score: 24.45
# Episode 70	Average Score: 23.64
# Episode 80	Average Score: 24.04
# Episode 90	Average Score: 23.80
# Episode 100	Average Score: 23.85
# Episode 110	Average Score: 23.74
# Episode 120	Average Score: 22.91
# Episode 130	Average Score: 22.49
# Episode 140	Average Score: 22.45
# Episode 150	Average Score: 21.01
# Episode 160	Average Score: 20.38
# Episode 170	Average Score: 20.50
# Episode 180	Average Score: 20.18
# Episode 190	Average Score: 19.93
# Episode 200	Average Score: 19.42
# Episode 210	Average Score: 19.38
# Episode 220	Average Score: 19.35
# Episode 230	Average Score: 18.83
# Episode 240	Average Score: 18.93
# Episode 250	Average Score: 19.22
# Episode 260	Average Score: 19.17
# Episode 270	Average Score: 19.67
# Episode 280	Average Score: 19.25
# Episode 290	Average Score: 19.17
# Episode 300	Average Score: 18.78
# Episode 310	Average Score: 18.41
# Episode 320	Average Score: 18.23
# Episode 330	Average Score: 18.20
# Episode 340	Average Score: 18.26
# Episode 350	Average Score: 18.02
# Episode 360	Average Score: 18.10
# Episode 370	Average Score: 17.41
# Episode 380	Average Score: 17.33
# Episode 390	Average Score: 17.02
# Episode 400	Average Score: 16.79
# Episode 410	Average Score: 16.84
# Episode 420	Average Score: 17.42
# Episode 430	Average Score: 17.45
# Episode 440	Average Score: 17.32
# Episode 450	Average Score: 17.15
# Episode 460	Average Score: 17.21
# Episode 470	Average Score: 16.92
# Episode 480	Average Score: 16.45
# Episode 490	Average Score: 16.55
# Episode 500	Average Score: 16.78
# Episode 510	Average Score: 16.54
# Episode 520	Average Score: 15.70
# Episode 530	Average Score: 15.71
# Episode 540	Average Score: 15.91
# Episode 550	Average Score: 15.86
# Episode 560	Average Score: 15.43
# Episode 570	Average Score: 15.79
# Episode 580	Average Score: 15.88
# Episode 590	Average Score: 15.77
# Episode 600	Average Score: 15.78
# Episode 610	Average Score: 15.59
# Episode 620	Average Score: 15.71
# Episode 630	Average Score: 15.62
# Episode 640	Average Score: 15.23
# Episode 650	Average Score: 15.28
# Episode 660	Average Score: 15.65
# Episode 670	Average Score: 15.20
# Episode 680	Average Score: 15.17
# Episode 690	Average Score: 15.34
# Episode 700	Average Score: 15.38
# Episode 710	Average Score: 15.53
# Episode 720	Average Score: 15.48
# Episode 730	Average Score: 15.39
# Episode 740	Average Score: 15.57
# Episode 750	Average Score: 15.64
# Episode 760	Average Score: 15.42
# Episode 770	Average Score: 15.38
# Episode 780	Average Score: 15.46
# Episode 790	Average Score: 15.46
# Episode 800	Average Score: 15.73
# Episode 810	Average Score: 15.60
# Episode 820	Average Score: 15.62
# Episode 830	Average Score: 15.54
# Episode 840	Average Score: 15.60
# Episode 850	Average Score: 15.50
# Episode 860	Average Score: 15.25
# Episode 870	Average Score: 15.67
# Episode 880	Average Score: 15.48
# Episode 890	Average Score: 15.58
# Episode 900	Average Score: 15.27
# Episode 910	Average Score: 15.52
# Episode 920	Average Score: 15.63
# Episode 930	Average Score: 16.75
# Episode 940	Average Score: 17.32
# Episode 950	Average Score: 17.23
# Episode 960	Average Score: 17.34
# Episode 970	Average Score: 16.75
# Episode 980	Average Score: 16.61
# Episode 990	Average Score: 16.27
# Episode 1000	Average Score: 15.99
# Episode 1010	Average Score: 16.78
# Episode 1020	Average Score: 16.70
# Episode 1030	Average Score: 16.04
# Episode 1040	Average Score: 15.66
# Episode 1050	Average Score: 16.31
# Episode 1060	Average Score: 16.34
# Episode 1070	Average Score: 16.59
# Episode 1080	Average Score: 17.76
# Episode 1090	Average Score: 17.54
# Episode 1100	Average Score: 18.33
# Episode 1110	Average Score: 17.68
# Episode 1120	Average Score: 18.42
# Episode 1130	Average Score: 18.59
# Episode 1140	Average Score: 18.03
# Episode 1150	Average Score: 17.80
# Episode 1160	Average Score: 18.01
# Episode 1170	Average Score: 17.93
# Episode 1180	Average Score: 17.96
# Episode 1190	Average Score: 18.92
# Episode 1200	Average Score: 18.86
# Episode 1210	Average Score: 19.12
# Episode 1220	Average Score: 19.48
# Episode 1230	Average Score: 19.19
# Episode 1240	Average Score: 21.90
# Episode 1250	Average Score: 22.37
# Episode 1260	Average Score: 23.43
# Episode 1270	Average Score: 26.09
# Episode 1280	Average Score: 25.44
# Episode 1290	Average Score: 25.59
# Episode 1300	Average Score: 28.34
# Episode 1310	Average Score: 29.32
# Episode 1320	Average Score: 32.31
# Episode 1330	Average Score: 40.40
# Episode 1340	Average Score: 42.59
# Episode 1350	Average Score: 45.93
# Episode 1360	Average Score: 61.07
# Episode 1370	Average Score: 72.05
# Episode 1380	Average Score: 82.71
# Episode 1390	Average Score: 98.77
# Episode 1400	Average Score: 112.28
# Episode 1410	Average Score: 129.52
# Episode 1420	Average Score: 141.37
# Episode 1430	Average Score: 150.81
# Episode 1440	Average Score: 163.74
# Episode 1450	Average Score: 174.17
# Episode 1460	Average Score: 176.11
# Episode 1470	Average Score: 177.77
# Episode 1480	Average Score: 182.96
# Episode 1490	Average Score: 184.21
# Episode 1500	Average Score: 185.17
# Episode 1510	Average Score: 182.76
# Episode 1520	Average Score: 185.90
# Episode 1530	Average Score: 186.78
# Episode 1540	Average Score: 186.32
# Episode 1550	Average Score: 191.89
# Episode 1560	Average Score: 191.70
# Episode 1570	Average Score: 194.76
# Episode 1580	Average Score: 195.18
# Episode 1590	Average Score: 197.60
# Episode 1600	Average Score: 199.51
# Episode 1610	Average Score: 202.79
# Episode 1620	Average Score: 204.33
# Episode 1630	Average Score: 206.73
# Episode 1640	Average Score: 210.69
# Episode 1650	Average Score: 211.24
# Episode 1660	Average Score: 214.37
# Episode 1670	Average Score: 215.93
# Episode 1680	Average Score: 218.92
# Episode 1690	Average Score: 218.68
# Episode 1700	Average Score: 218.12
# Episode 1710	Average Score: 218.59
# Episode 1720	Average Score: 219.02
# Episode 1730	Average Score: 217.92
# Episode 1740	Average Score: 217.43
# Episode 1750	Average Score: 218.40
# Episode 1760	Average Score: 217.85
# Episode 1770	Average Score: 219.20
# Episode 1780	Average Score: 220.33
# Episode 1790	Average Score: 219.59
# Episode 1800	Average Score: 220.33
# Episode 1810	Average Score: 220.03
# Episode 1820	Average Score: 219.26
# Episode 1830	Average Score: 218.35
# Episode 1840	Average Score: 216.97
# Episode 1850	Average Score: 213.34
# Episode 1860	Average Score: 212.13
# Episode 1870	Average Score: 211.16
# Episode 1880	Average Score: 210.48
# Episode 1890	Average Score: 211.21
# Episode 1900	Average Score: 212.40
# Episode 1910	Average Score: 214.22
# Episode 1920	Average Score: 214.50
# Episode 1930	Average Score: 218.12
# Episode 1940	Average Score: 219.62
# Episode 1950	Average Score: 222.03
# Episode 1960	Average Score: 225.47
# Episode 1970	Average Score: 227.26
# Episode 1980	Average Score: 227.13
# Episode 1990	Average Score: 227.13
# Episode 2000	Average Score: 227.00
# Episode 2010	Average Score: 226.72
# Episode 2020	Average Score: 226.28
# Episode 2030	Average Score: 224.83
# Episode 2040	Average Score: 225.83
# Episode 2050	Average Score: 226.77
# Episode 2060	Average Score: 222.62
# Episode 2070	Average Score: 221.77
# Episode 2080	Average Score: 221.68
# Episode 2090	Average Score: 222.77
# Episode 2100	Average Score: 221.47
# Episode 2110	Average Score: 220.56
# Episode 2120	Average Score: 224.85
# Episode 2130	Average Score: 223.65
# Episode 2140	Average Score: 223.55
# Episode 2150	Average Score: 221.09
# Episode 2160	Average Score: 221.99
# Episode 2170	Average Score: 221.24
# Episode 2180	Average Score: 221.11
# Episode 2190	Average Score: 219.21
# Episode 2200	Average Score: 219.29
# Episode 2210	Average Score: 217.68
# Episode 2220	Average Score: 211.29
# Episode 2230	Average Score: 208.33
# Episode 2240	Average Score: 206.77
# Episode 2250	Average Score: 205.87
# Episode 2260	Average Score: 204.55
# Episode 2270	Average Score: 201.56
# Episode 2280	Average Score: 199.60
# Episode 2290	Average Score: 198.27
# Episode 2300	Average Score: 195.93
# Episode 2310	Average Score: 195.19
# Episode 2320	Average Score: 195.81
# Episode 2330	Average Score: 196.61
# Episode 2340	Average Score: 194.13
# Episode 2350	Average Score: 193.42
# Episode 2360	Average Score: 191.89
# Episode 2370	Average Score: 190.72
# Episode 2380	Average Score: 189.89
# Episode 2390	Average Score: 188.58
# Episode 2400	Average Score: 189.61
# Episode 2410	Average Score: 188.47
# Episode 2420	Average Score: 186.02
# Episode 2430	Average Score: 183.99
# Episode 2440	Average Score: 183.20
# Episode 2450	Average Score: 181.92
# Episode 2460	Average Score: 180.63
# Episode 2470	Average Score: 180.38
# Episode 2480	Average Score: 179.60
# Episode 2490	Average Score: 178.87
# Episode 2500	Average Score: 176.68
# Episode 2510	Average Score: 176.70
# Episode 2520	Average Score: 176.59
# Episode 2530	Average Score: 177.17
# Episode 2540	Average Score: 176.30
# Episode 2550	Average Score: 176.20
# Episode 2560	Average Score: 175.67
# Episode 2570	Average Score: 175.08
# Episode 2580	Average Score: 174.76
# Episode 2590	Average Score: 175.70
# Episode 2600	Average Score: 174.76
# Episode 2610	Average Score: 173.88
# Episode 2620	Average Score: 173.87
# Episode 2630	Average Score: 173.36
# Episode 2640	Average Score: 173.28
# Episode 2650	Average Score: 172.93
# Episode 2660	Average Score: 173.73
# Episode 2670	Average Score: 174.40
# Episode 2680	Average Score: 174.10
# Episode 2690	Average Score: 172.95
# Episode 2700	Average Score: 173.18
# Episode 2710	Average Score: 172.42
# Episode 2720	Average Score: 171.30
# Episode 2730	Average Score: 170.84
# Episode 2740	Average Score: 170.30
# Episode 2750	Average Score: 169.48
# Episode 2760	Average Score: 168.63
# Episode 2770	Average Score: 167.73
# Episode 2780	Average Score: 168.30
# Episode 2790	Average Score: 167.52
# Episode 2800	Average Score: 166.91
# Episode 2810	Average Score: 166.57
# Episode 2820	Average Score: 166.58
# Episode 2830	Average Score: 167.65
# Episode 2840	Average Score: 167.11
# Episode 2850	Average Score: 165.62
# Episode 2860	Average Score: 163.40
# Episode 2870	Average Score: 162.98
# Episode 2880	Average Score: 161.12
# Episode 2890	Average Score: 160.65
# Episode 2900	Average Score: 161.64
# Episode 2910	Average Score: 161.10
# Episode 2920	Average Score: 160.27
# Episode 2930	Average Score: 157.95
# Episode 2940	Average Score: 158.29
# Episode 2950	Average Score: 159.48
# Episode 2960	Average Score: 160.57
# Episode 2970	Average Score: 160.44
# Episode 2980	Average Score: 160.18
# Episode 2990	Average Score: 159.42
# Episode 3000	Average Score: 157.42
# Episode 3010	Average Score: 156.95
# Episode 3020	Average Score: 157.02
# Episode 3030	Average Score: 156.90
# Episode 3040	Average Score: 156.25
# Episode 3050	Average Score: 155.71
# Episode 3060	Average Score: 155.98
# Episode 3070	Average Score: 155.80
# Episode 3080	Average Score: 155.46
# Episode 3090	Average Score: 155.03
# Episode 3100	Average Score: 155.06
# Episode 3110	Average Score: 154.97
# Episode 3120	Average Score: 154.98
# Episode 3130	Average Score: 154.98
# Episode 3140	Average Score: 154.36
# Episode 3150	Average Score: 154.66
# Episode 3160	Average Score: 154.51
# Episode 3170	Average Score: 153.97
# Episode 3180	Average Score: 153.94
# Episode 3190	Average Score: 153.68
# Episode 3200	Average Score: 153.58
# Episode 3210	Average Score: 153.26
# Episode 3220	Average Score: 152.84
# Episode 3230	Average Score: 152.88
# Episode 3240	Average Score: 152.96
# Episode 3250	Average Score: 152.26
# Episode 3260	Average Score: 151.88
# Episode 3270	Average Score: 151.64
# Episode 3280	Average Score: 151.85
# Episode 3290	Average Score: 152.63
# Episode 3300	Average Score: 152.89
# Episode 3310	Average Score: 153.93
# Episode 3320	Average Score: 153.43
# Episode 3330	Average Score: 152.27
# Episode 3340	Average Score: 151.75
# Episode 3350	Average Score: 151.67
# Episode 3360	Average Score: 151.61
# Episode 3370	Average Score: 151.48
# Episode 3380	Average Score: 151.13
# Episode 3390	Average Score: 150.53
# Episode 3400	Average Score: 150.29
# Episode 3410	Average Score: 148.65
# Episode 3420	Average Score: 148.73
# Episode 3430	Average Score: 149.19
# Episode 3440	Average Score: 149.51
# Episode 3450	Average Score: 149.19
# Episode 3460	Average Score: 149.15
# Episode 3470	Average Score: 149.03
# Episode 3480	Average Score: 148.76
# Episode 3490	Average Score: 148.57
# Episode 3500	Average Score: 148.16
# Episode 3510	Average Score: 148.30
# Episode 3520	Average Score: 147.89
# Episode 3530	Average Score: 147.75
# Episode 3540	Average Score: 147.43
# Episode 3550	Average Score: 147.36
# Episode 3560	Average Score: 146.92
# Episode 3570	Average Score: 146.93
# Episode 3580	Average Score: 147.19
# Episode 3590	Average Score: 147.47
# Episode 3600	Average Score: 147.47
# Episode 3610	Average Score: 147.57
# Episode 3620	Average Score: 148.05
# Episode 3630	Average Score: 148.16
# Episode 3640	Average Score: 147.82
# Episode 3650	Average Score: 147.62
# Episode 3660	Average Score: 148.13
# Episode 3670	Average Score: 147.83
# Episode 3680	Average Score: 147.62
# Episode 3690	Average Score: 147.31
# Episode 3700	Average Score: 147.09
# Episode 3710	Average Score: 147.08
# Episode 3720	Average Score: 146.85
# Episode 3730	Average Score: 146.63
# Episode 3740	Average Score: 146.79
# Episode 3750	Average Score: 145.58
# Episode 3760	Average Score: 145.18
# Episode 3770	Average Score: 144.75
# Episode 3780	Average Score: 144.39
# Episode 3790	Average Score: 143.82
# Episode 3800	Average Score: 143.61
# Episode 3810	Average Score: 143.41
# Episode 3820	Average Score: 142.88
# Episode 3830	Average Score: 143.30
# Episode 3840	Average Score: 143.38
# Episode 3850	Average Score: 145.09
# Episode 3860	Average Score: 145.41
# Episode 3870	Average Score: 146.07
# Episode 3880	Average Score: 146.63
# Episode 3890	Average Score: 147.90
# Episode 3900	Average Score: 148.78
# Episode 3910	Average Score: 149.14
# Episode 3920	Average Score: 149.63
# Episode 3930	Average Score: 150.08
# Episode 3940	Average Score: 151.02
# Episode 3950	Average Score: 151.15
# Episode 3960	Average Score: 151.96
# Episode 3970	Average Score: 151.65
# Episode 3980	Average Score: 152.19
# Episode 3990	Average Score: 151.68
# Episode 4000	Average Score: 151.32
# Episode 4010	Average Score: 152.83
# Episode 4020	Average Score: 154.50
# Episode 4030	Average Score: 155.61
# Episode 4040	Average Score: 156.86
# Episode 4050	Average Score: 161.64
# Episode 4060	Average Score: 164.74
# Episode 4070	Average Score: 168.47
# Episode 4080	Average Score: 171.51
# Episode 4090	Average Score: 178.85
# Episode 4100	Average Score: 186.10
# Episode 4110	Average Score: 191.49
# Episode 4120	Average Score: 196.81
# Episode 4130	Average Score: 205.41
# Episode 4140	Average Score: 220.64
# Episode 4150	Average Score: 233.10
# Episode 4160	Average Score: 244.25
# Episode 4170	Average Score: 247.73
# Episode 4180	Average Score: 249.41
# Episode 4190	Average Score: 251.95
# Episode 4200	Average Score: 251.44
# Episode 4210	Average Score: 249.73
# Episode 4220	Average Score: 252.14
# Episode 4230	Average Score: 247.21
# Episode 4240	Average Score: 235.96
# Episode 4250	Average Score: 224.34
# Episode 4260	Average Score: 211.50
# Episode 4270	Average Score: 206.48
# Episode 4280	Average Score: 201.27
# Episode 4290	Average Score: 191.45
# Episode 4300	Average Score: 185.01
# Episode 4310	Average Score: 180.74
# Episode 4320	Average Score: 171.46
# Episode 4330	Average Score: 164.20
# Episode 4340	Average Score: 157.55
# Episode 4350	Average Score: 152.14
# Episode 4360	Average Score: 151.30
# Episode 4370	Average Score: 150.86
# Episode 4380	Average Score: 151.72
# Episode 4390	Average Score: 150.68
# Episode 4400	Average Score: 151.07
# Episode 4410	Average Score: 150.44
# Episode 4420	Average Score: 150.80
# Episode 4430	Average Score: 153.36
# Episode 4440	Average Score: 154.63
# Episode 4450	Average Score: 153.82
# Episode 4460	Average Score: 152.92
# Episode 4470	Average Score: 152.93
# Episode 4480	Average Score: 156.35
# Episode 4490	Average Score: 160.18
# Episode 4500	Average Score: 161.26
# Episode 4510	Average Score: 160.99
# Episode 4520	Average Score: 164.23
# Episode 4530	Average Score: 164.25
# Episode 4540	Average Score: 165.73
# Episode 4550	Average Score: 170.22
# Episode 4560	Average Score: 172.69
# Episode 4570	Average Score: 172.64
# Episode 4580	Average Score: 173.84
# Episode 4590	Average Score: 173.71
# Episode 4600	Average Score: 175.07
# Episode 4610	Average Score: 181.45
# Episode 4620	Average Score: 180.03
# Episode 4630	Average Score: 182.43
# Episode 4640	Average Score: 183.44
# Episode 4650	Average Score: 182.92
# Episode 4660	Average Score: 181.21
# Episode 4670	Average Score: 181.76
# Episode 4680	Average Score: 178.89
# Episode 4690	Average Score: 177.61
# Episode 4700	Average Score: 177.38
# Episode 4710	Average Score: 173.54
# Episode 4720	Average Score: 174.97
# Episode 4730	Average Score: 174.24
# Episode 4740	Average Score: 175.78
# Episode 4750	Average Score: 175.06
# Episode 4760	Average Score: 176.30

# %%
env.close()

# %% [markdown]
# ## Concluding Thoughts
#
# To train a well performing model, we most likely need to increase the number of episodes, `n_episodes`, and also increase the number of layers and nodes within each.
# Furthermore, while DQN was one of the first deep RL algorithms to solve Atari, several advances in the field of RL have developed novel algorithms that outperform DQN.
# Several of these algorithms are already tailored for use within the RLlib package.
#
# `DroneDodgeBall` is a complex environment and will take significant time to solve.
# Do not be discouraged if you are not getting good training results in a short period of time.
#
# Below is an example of a larger model training for a longer period of time.

# %% [markdown]
# __Example Results of a Well Trained Model__
#
# The following graph is a training log of a policy-based agent trained over 8 million steps (~60,000 episodes).
# This training took about 16 hours on the MIT supercomputer.
#
# ![ray_learned](images/ray_learned.png)
#
# It is important to remember that reinforcement learning alogrithms can take an extremely long time to train.
# DeepMind AlphaStar, one of the most advanced RL algorithms that learned to play Starcraft, took over 46 years worth of training time on TPUv3s, some of the most powerful processors on the planet.
