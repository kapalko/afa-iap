# %% [markdown]
# # Getting Started with the Air Force Arcade
#
# ---
#
# In this notebook, we will introduce you to the Air Force Arcade and reinforcement learning by demonstrating some basic functionality of the environments, the basics of gym environments, and finally will train a small [Deep Q Network (DQN)](https://arxiv.org/pdf/1312.5602.pdf) to get you started.

# %% [markdown]
# ## Step 0: About the Environment
#
# The `Aerial Refuelling` environment places a quadcopter (the drone) in an arena with a ball launcher.
# The drone must avoid the launched balls while moving towards and staying hovering on a fixed waypoint in the environment.

# %% [markdown]
# __Rewards__

# %% [markdown]
# ## Step 1: Start the Environment
#
# First, we will import the necessary packages.

# %%
import gym
import airforce_arcade
import numpy as np
from collections import deque
import torch
import matplotlib.pyplot as plt
import datetime
import copy
from torch.autograd import Variable
import random
from PIL import Image
from IPython.display import clear_output
import math
import time
from gym.spaces import Dict, Discrete, Box, Tuple
# %matplotlib inline

# %% [markdown]
# Now we will create gym environment. In this step, we use OpenAI's [Gym](https://gym.openai.com/) API to relay the information from our game to Python so we can capture the relevant information.

# %%
# create and launch the environment
env  =  gym.make('MountainCar-v0')

# %% [markdown]
# ## Step 2: Examine the State and Action Spaces of the Environment

# %%
# number of actions
action_size = env.action_space
print('Action Space:', action_size)

# examine the state space 
state = env.observation_space
print('Observations look like:', state)
# Out:
# Action Space: Discrete(3)
# Observations look like: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)

# %%
state = env.reset()
state
# Out:
# array([-0.40776095,  0.        ])

# %%
def plot_res(values, title=''):   
    ''' Plot the reward curve and histogram of results over time.'''
    # Update the window after each episode
    clear_output(wait=True)
    
    # Define the figure
    f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
    f.suptitle(title)
    ax[0].plot(values, label='score per run')
    ax[0].axhline(195, c='red',ls='--', label='goal')
    ax[0].set_xlabel('Episodes')
    ax[0].set_ylabel('Reward')
    x = range(len(values))
    ax[0].legend()
    # Calculate the trend
    try:
        z = np.polyfit(x, values, 1)
        p = np.poly1d(z)
        ax[0].plot(x,p(x),"--", label='trend')
    except:
        print('')
    
    # Plot the histogram of results
    ax[1].hist(values[-50:])
    ax[1].axvline(195, c='red', label='goal')
    ax[1].set_xlabel('Scores per Last 50 Episodes')
    ax[1].set_ylabel('Frequency')
    ax[1].legend()
    plt.show()

# %%
def random_search(env, episodes, 
                  title='Random Strategy'):
    """ Random search strategy implementation."""
    final = []
    for episode in range(episodes):
        state = env.reset()
        done = False
        total = 0
        while not done:
            # Sample random actions
            action = env.action_space.sample()
            # Take action and extract results
            next_state, reward, done, _ = env.step(action)
            # Update reward
            total += reward
            if done:
                break
        # Add to the final reward
        final.append(total)
        plot_res(final,title)
    return final

# %% [markdown]
# You should see a result that looks like:
# ```
# Action Space: MultiDiscrete([3 3 3 3])
# States look like: Box(-inf, inf, (1254,), float32)
# ```
#
# So what does this mean?
#
# For our `DroneDodgeBall` environment, the drone has `4` different discrete actions it can take, with a zero, low, or high action for each.
# These correspond to roll, pitch, thrust, and yaw.
#
# For the state space, these are the observations that the drone receives.
# These are the inputs to your model and what your RL agent learns to recognize and take actions off of.
# In `DroneDodgeBall`, there are `1254` observations representing the drone's ray-based perception of its environment and a 6-vector of nomalized drone position and relative waypoint position.

# %% [markdown]
# ## Step 3: Take Random Actions
#
# In this next cell, we will see how the Gym API interacts with the environment by taking random actions.
# We will also explore how to receive information from the environment that will allow us to train our agents.
#
# You should be able to view the drone's behaviors in the `DroneDodgeBall` game window.
# Since the agent will be making random movements, it will look a bit erratic.

# %%
random_s = random_search(env, 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-75f8e2b6bf93> in <module>
# ----> 1 random_s = random_search(env, 1000)
#
# <ipython-input-17-67aaf99d5aa1> in random_search(env, episodes, title)
#      18         # Add to the final reward
#      19         final.append(total)
# ---> 20         plot_res(final,title)
#      21     return final
#
# <ipython-input-16-e2ea130b27ac> in plot_res(values, title)
#       5
#       6     # Define the figure
# ----> 7     f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
#       8     f.suptitle(title)
#       9     ax[0].plot(values, label='score per run')
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1108         self.containers = []
#    1109
# -> 1110         self.grid(False)  # Disable grid on init to use rcParameter
#    1111         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1112                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2890             self.xaxis.grid(b, which=which, **kwargs)
#    2891         if axis in ['y', 'both']:
# -> 2892             self.yaxis.grid(b, which=which, **kwargs)
#    2893
#    2894     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1449             elif b is not None:
#    1450                 gridkw['gridOn'] = b
# -> 1451             self.set_tick_params(which='major', **gridkw)
#    1452         self.stale = True
#    1453
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     836             if which in ['major', 'both']:
#     837                 self._major_tick_kw.update(kwtrans)
# --> 838                 for tick in self.majorTicks:
#     839                     tick._apply_params(**kwtrans)
#     840             if which in ['minor', 'both']:
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     616             if self._major:
#     617                 instance.majorTicks = []
# --> 618                 tick = instance._get_tick(major=True)
#     619                 instance.majorTicks.append(tick)
#     620                 return instance.majorTicks
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2304         else:
#    2305             tick_kw = self._minor_tick_kw
# -> 2306         return YTick(self.axes, 0, major=major, **tick_kw)
#    2307
#    2308     def set_label_position(self, position):
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     506         # the y loc is 3 points below the min of y axis
#     507         trans, va, ha = self._get_text1_transform()
# --> 508         self.label1.set(
#     509             x=0, y=0,
#     510             verticalalignment=va, horizontalalignment=ha, transform=trans,
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1086     def set(self, **kwargs):
#    1087         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1088         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1089         move_color_to_start = False
#    1090         if "color" in kwargs:
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     384     @functools.wraps(func)
#     385     def wrapper(*inner_args, **inner_kwargs):
# --> 386         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     387         if is_varargs and arguments.get(name):
#     388             warn_deprecated(
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/inspect.py in bind(self, *args, **kwargs)
#    3023         if the passed arguments can not be bound.
#    3024         """
# -> 3025         return self._bind(args, kwargs)
#    3026
#    3027     def bind_partial(self, /, *args, **kwargs):
#
# ~/opt/anaconda3/envs/CRSP/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    2892         arguments = OrderedDict()
#    2893
# -> 2894         parameters = iter(self.parameters.values())
#    2895         parameters_ex = ()
#    2896         arg_vals = iter(args)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 4: Train your First Model
#
# Unity can sometimes be finicky.
# If you can't get training to start, or it seems that the notebook is lagging, restart your kernel and run steps 0-2.
#
# ![Kernel Restart](images/kernel_restart.png)
#
# __Note:__ These environments are advanced and will require significant training.
# The code provided demonstrates the basics of training a model but will most likely not train a highly sophisticated autonomous agent.

# %% [markdown]
# __Training a Deep Q-Network__
#
# This starter code runs for only 50 episodes.
# On a local computer, this can take between 5-10 minutes.
# You may notice that the agent doesn't really learn much.
# In fact, our training required several thousand training episodes to begin to learn appropriate behaviors.
#
# There are two supporting files required to run this code:
# - `dqn_agent.py` defines the functions of the agent, including how to select actions, take steps, and save experiences for your networks to train on
# - `model.py` is the defined architecture of the neural network. In this example, it's a small 3 layer network with 64 hidden nodes per layer.

# %%
from dqn_agent import Agent
agent = Agent(state_size=2, action_size=3, seed=42)


def dqn(n_episodes=100, max_t=200, eps_start=1.0, eps_end=0.01, eps_decay=0.05):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    max_position = -.4
    positions = np.ndarray([0,2])
    rewards = []
    successful = []
    for episode in range(1000):
        running_reward = 0
        env.reset()
        done = False
        for i_episode in range(1, n_episodes+1):
            action = agent.act(state, eps)
            next_state, reward, done, info = env.step(action)
            # Give a reward for reaching a new maximum position
            if state[0] > max_position:
                max_position = state[0]
                positions = np.append(positions, [[episode, max_position]], axis=0)
                running_reward += 10
            else:
                running_reward += reward
            if done: 
                if state[0] >= 0.5:
                    successful.append(episode)
                rewards.append(running_reward)
                break
        scores_window.append(running_reward)       # save most recent score
        scores.append(running_reward)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
#         print('\rEpisode {}\tAverage Score: {:.2f}\n'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 10 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode, np.mean(scores_window)))
    torch.save(agent.qnetwork_local.state_dict(), 'checkpoints/checkpoint_local.pth')
    torch.save(agent.qnetwork_target.state_dict(), 'checkpoints/checkpoint_target.pth')
    return scores

scores = dqn()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-56804ae344c9> in <module>
# ----> 1 from tqdm import tqdm, trange
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
import sys
# !{sys.executable} -m pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.61.1-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.3 MB/s eta 0:00:01
# Installing collected packages: tqdm
# Successfully installed tqdm-4.61.1

# %%
pip list
# Out:
# Package                       Version             Location
# ----------------------------- ------------------- ---------------------------------------------------------------------
# absl-py                       0.12.0
# aiohttp                       3.7.4.post0
# aiohttp-cors                  0.7.0
# aioredis                      1.3.1
# airforce-arcade               0.0.1               /Users/nadeemdamanhuri/Desktop/CRSP/afa-iap/baselines/airforce-arcade
# appnope                       0.1.2
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-generator               1.10
# async-timeout                 3.0.1
# attrs                         21.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.0
# blessings                     1.7
# cachetools                    4.2.2
# cattrs                        1.7.1
# certifi                       2021.5.30
# cffi                          1.14.5
# chardet                       4.0.0
# click                         8.0.1
# cloudpickle                   1.6.0
# colorama                      0.4.4
# cycler                        0.10.0
# decorator                     5.0.9
# defusedxml                    0.7.1
# dm-tree                       0.1.6
# entrypoints                   0.3
# filelock                      3.0.12
# flatbuffers                   1.12
# gast                          0.4.0
# google-api-core               1.30.0
# google-auth                   1.31.0
# google-auth-oauthlib          0.4.4
# google-pasta                  0.2.0
# googleapis-common-protos      1.53.0
# gpustat                       0.6.0
# grpcio                        1.34.1
# gym                           0.18.3
# h5py                          3.1.0
# hiredis                       2.0.0
# idna                          2.10
# importlib-metadata            4.5.0
# ipykernel                     5.5.5
# ipython                       7.24.1
# ipython-genutils              0.2.0
# jedi                          0.18.0
# Jinja2                        3.0.1
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyterlab-pygments           0.1.2
# keras-nightly                 2.5.0.dev2021032900
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# lz4                           3.1.3
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.3.4
# matplotlib-inline             0.1.2
# mistune                       0.8.4
# mkl-fft                       1.3.0
# mkl-random                    1.2.1
# mkl-service                   2.3.0
# mlagents                      0.25.0
# mlagents-envs                 0.25.0
# msgpack                       1.0.2
# multidict                     5.1.0
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# notebook                      6.4.0
# numpy                         1.19.5
# nvidia-ml-py3                 7.352.0
# oauthlib                      3.1.1
# olefile                       0.46
# opencensus                    0.7.13
# opencensus-context            0.1.2
# opencv-python                 4.5.2.54
# opencv-python-headless        4.3.0.36
# opt-einsum                    3.3.0
# packaging                     20.9
# pandas                        1.2.4
# pandocfilters                 1.4.2
# parso                         0.8.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.2.0
# pip                           21.1.2
# prometheus-client             0.11.0
# prompt-toolkit                3.0.18
# protobuf                      3.17.3
# psutil                        5.8.0
# ptyprocess                    0.7.0
# py-spy                        0.3.7
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.20
# pydantic                      1.8.2
# pyglet                        1.5.15
# Pygments                      2.9.0
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# python-dateutil               2.8.1
# pytz                          2021.1
# PyYAML                        5.4.1
# pyzmq                         20.0.0
# ray                           1.4.0
# redis                         3.5.3
# requests                      2.25.1
# requests-oauthlib             1.3.0
# rsa                           4.7.2
# scipy                         1.6.3
# Send2Trash                    1.5.0
# setuptools                    52.0.0.post20210125
# six                           1.16.0
# tabulate                      0.8.9
# tensorboard                   2.5.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorboardX                  2.2
# tensorflow                    2.5.0
# tensorflow-estimator          2.5.0
# termcolor                     1.1.0
# terminado                     0.10.1
# testpath                      0.5.0
# torch                         1.8.1
# tornado                       6.1
# tqdm                          4.61.1
# traitlets                     5.0.5
# typing-extensions             3.7.4.3
# urllib3                       1.26.5
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      2.0.1
# wheel                         0.36.2
# wrapt                         1.12.1
# yarl                          1.6.3
# zipp                          3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
state = env.reset()
for t in range(10000):
    env.render()
    state, reward, done, _ = env.step(np.random.randint(0,3))
    if done:
        break
